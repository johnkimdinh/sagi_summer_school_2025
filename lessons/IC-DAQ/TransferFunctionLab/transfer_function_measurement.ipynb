# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# - instrument driver imports, uncomment the device which you are using - #
import kmoon_fy6900_fgen_solution as fgen_funcs
#import siglent_sdg2082x_fgen as fgen_funcs
import siglent_sds1104xe_oscope as scope_funcs

# %%
fgen = fgen_funcs.connect(0)

# %%
fgen_funcs.set_channel_state(fgen, 1, 'OFF')
